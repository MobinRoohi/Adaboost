# %% [markdown]
# # Project: LeNet Convolutional Network MNIST
#
#
# ## Introduction
# In this notebook, we aim to implement one of the most famous and original covolutional networks called the "LeNet", first proposed by Yann LeCun et al. in 1998. The implemented will be closer to the original model. We will then use the model to perform handwritten digit recognition using the MNIST dataset. We will use the PyTorch framework to build and train the model. In a separate notebook, we will also implement a multi-layer perceptron (MLP) model to perform the same task and then compare LeNet's performance against the MLP's both in their accuracy and robustness, as well as their translation invariance properties.
#
# We will begin by importing the necessary packages and frameworks.

# %% [markdown]
# ## Import Libraries and Packages

# %%
import numpy as np           
import matplotlib.pyplot as plt    
import pandas as pd
import torch          
import torchvision
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torch.functional as F

# %% [markdown]
# ## Import Dataset and Preprocessing

# %%
# Define a transform to normalize the data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# Download and load the training dataset
trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test dataset
testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

dataiter = iter(trainloader)
images, labels = next(dataiter)
images_np = images.numpy()
labels_np = labels.numpy()

print(f'Batch shape: {images_np.shape}')  
print(f'Batch label shape: {labels_np.shape}')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 15829170.19it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 464846.31it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 4320730.84it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2746616.03it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Batch shape: (64, 1, 28, 28)
# Batch label shape: (64,)

# %% [markdown]
# ## LeNet Architecture

# %%
class LeNet(nn.Module):

    def __init__(self):
        super(LeNet, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 6, 5, padding=2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        
        # Average Pooling Layers
        self.pool1 = nn.AvgPool2d(2, stride=2)
        self.pool2 = nn.AvgPool2d(2, stride=2)
        
        # Fully connected layers
        self.fc1 = nn.Linear(5 * 5 * 16, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        
        # Sigmoid as fully connected layer activation
        self.activation = nn.Sigmoid()
        
    def forward(self, x):
        # Forward prop
        
        # Layer 1 (conv + pool)
        x = self.conv1(x)
        x = self.pool1(x)
        x = self.activation(x)
        
        # Layer 2 (conv + pool)
        x = self.conv2(x)
        x = self.pool2(x)
        x = self.activation(x)
        
        # Flatten
        x = x.view(x.size(0), -1)
        
        # Fully Dense Layers
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        x = self.activation(x)
        x = self.fc3(x)
        
        return x

# %%
# Check for GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Initialize model
model = LeNet()
print(model)

# Move the model to the device of choice
model = model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# Using device: cuda
# LeNet(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (pool2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
#   (activation): Sigmoid()
# )

# %% [markdown]
# ## Model Training

# %%
log = []
for epoch in range(25):
    running_loss = 0
    
    for i, data in enumerate(trainloader, 0):
        # Input the training batch
        inputs, labels = data
        
        # Move data to the preferred device
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Reset the parameter gradients
        optimizer.zero_grad()
        
        # Forward prop
        outputs = model(inputs)
        
        # Loss
        loss = criterion(outputs, labels)
        log.append(loss.item()) 
        
        # Back prop
        loss.backward()
        optimizer.step()
        
        # Accumulate running loss
        running_loss += loss.item()
        
        # Print every 100 mini-batches
        if i % 200 == 99:
            print(f'Epoch [{epoch + 1}], Batch [{i + 1}], Loss: {running_loss / 100:.4f}')
            running_loss = 0.0
            
print("Training Complete!")
# Out:
# Epoch [1], Batch [100], Loss: 2.3097
# Epoch [1], Batch [300], Loss: 3.2174
# Epoch [1], Batch [500], Loss: 1.3521
# Epoch [1], Batch [700], Loss: 0.8449
# Epoch [1], Batch [900], Loss: 0.6696
# Epoch [2], Batch [100], Loss: 0.2943
# Epoch [2], Batch [300], Loss: 0.5187
# Epoch [2], Batch [500], Loss: 0.4586
# Epoch [2], Batch [700], Loss: 0.4222
# Epoch [2], Batch [900], Loss: 0.3807
# Epoch [3], Batch [100], Loss: 0.1686
# Epoch [3], Batch [300], Loss: 0.3344
# Epoch [3], Batch [500], Loss: 0.3051
# Epoch [3], Batch [700], Loss: 0.3209
# Epoch [3], Batch [900], Loss: 0.2788
# Epoch [4], Batch [100], Loss: 0.1288
# Epoch [4], Batch [300], Loss: 0.2590
# Epoch [4], Batch [500], Loss: 0.2531
# Epoch [4], Batch [700], Loss: 0.2347
# Epoch [4], Batch [900], Loss: 0.2187
# Epoch [5], Batch [100], Loss: 0.1028
# Epoch [5], Batch [300], Loss: 0.2141
# Epoch [5], Batch [500], Loss: 0.2047
# Epoch [5], Batch [700], Loss: 0.1905
# Epoch [5], Batch [900], Loss: 0.1951
# Epoch [6], Batch [100], Loss: 0.0890
# Epoch [6], Batch [300], Loss: 0.1697
# Epoch [6], Batch [500], Loss: 0.1794
# Epoch [6], Batch [700], Loss: 0.1663
# Epoch [6], Batch [900], Loss: 0.1747
# Epoch [7], Batch [100], Loss: 0.0795
# Epoch [7], Batch [300], Loss: 0.1559
# Epoch [7], Batch [500], Loss: 0.1456
# Epoch [7], Batch [700], Loss: 0.1472
# Epoch [7], Batch [900], Loss: 0.1428
# Epoch [8], Batch [100], Loss: 0.0599
# Epoch [8], Batch [300], Loss: 0.1405
# Epoch [8], Batch [500], Loss: 0.1388
# Epoch [8], Batch [700], Loss: 0.1387
# Epoch [8], Batch [900], Loss: 0.1250
# Epoch [9], Batch [100], Loss: 0.0562
# Epoch [9], Batch [300], Loss: 0.1189
# Epoch [9], Batch [500], Loss: 0.1175
# Epoch [9], Batch [700], Loss: 0.1265
# Epoch [9], Batch [900], Loss: 0.1273
# Epoch [10], Batch [100], Loss: 0.0534
# Epoch [10], Batch [300], Loss: 0.1018
# Epoch [10], Batch [500], Loss: 0.1140
# Epoch [10], Batch [700], Loss: 0.1049
# Epoch [10], Batch [900], Loss: 0.1101
# Epoch [11], Batch [100], Loss: 0.0434
# Epoch [11], Batch [300], Loss: 0.1068
# Epoch [11], Batch [500], Loss: 0.1012
# Epoch [11], Batch [700], Loss: 0.1001
# Epoch [11], Batch [900], Loss: 0.1010
# Epoch [12], Batch [100], Loss: 0.0424
# Epoch [12], Batch [300], Loss: 0.0991
# Epoch [12], Batch [500], Loss: 0.0888
# Epoch [12], Batch [700], Loss: 0.0899
# Epoch [12], Batch [900], Loss: 0.0870
# Epoch [13], Batch [100], Loss: 0.0368
# Epoch [13], Batch [300], Loss: 0.0830
# Epoch [13], Batch [500], Loss: 0.0843
# Epoch [13], Batch [700], Loss: 0.0900
# Epoch [13], Batch [900], Loss: 0.0904
# Epoch [14], Batch [100], Loss: 0.0448
# Epoch [14], Batch [300], Loss: 0.0741
# Epoch [14], Batch [500], Loss: 0.0708
# Epoch [14], Batch [700], Loss: 0.0808
# Epoch [14], Batch [900], Loss: 0.0699
# Epoch [15], Batch [100], Loss: 0.0343
# Epoch [15], Batch [300], Loss: 0.0698
# Epoch [15], Batch [500], Loss: 0.0700
# Epoch [15], Batch [700], Loss: 0.0756
# Epoch [15], Batch [900], Loss: 0.0768
# Epoch [16], Batch [100], Loss: 0.0311
# Epoch [16], Batch [300], Loss: 0.0571
# Epoch [16], Batch [500], Loss: 0.0645
# Epoch [16], Batch [700], Loss: 0.0659
# Epoch [16], Batch [900], Loss: 0.0812
# Epoch [17], Batch [100], Loss: 0.0257
# Epoch [17], Batch [300], Loss: 0.0555
# Epoch [17], Batch [500], Loss: 0.0637
# Epoch [17], Batch [700], Loss: 0.0745
# Epoch [17], Batch [900], Loss: 0.0672
# Epoch [18], Batch [100], Loss: 0.0299
# Epoch [18], Batch [300], Loss: 0.0467
# Epoch [18], Batch [500], Loss: 0.0546
# Epoch [18], Batch [700], Loss: 0.0585
# Epoch [18], Batch [900], Loss: 0.0604
# Epoch [19], Batch [100], Loss: 0.0232
# Epoch [19], Batch [300], Loss: 0.0505
# Epoch [19], Batch [500], Loss: 0.0632
# Epoch [19], Batch [700], Loss: 0.0597
# Epoch [19], Batch [900], Loss: 0.0527
# Epoch [20], Batch [100], Loss: 0.0256
# Epoch [20], Batch [300], Loss: 0.0393
# Epoch [20], Batch [500], Loss: 0.0431
# Epoch [20], Batch [700], Loss: 0.0540
# Epoch [20], Batch [900], Loss: 0.0559
# Epoch [21], Batch [100], Loss: 0.0248
# Epoch [21], Batch [300], Loss: 0.0446
# Epoch [21], Batch [500], Loss: 0.0348
# Epoch [21], Batch [700], Loss: 0.0495
# Epoch [21], Batch [900], Loss: 0.0427
# Epoch [22], Batch [100], Loss: 0.0154
# Epoch [22], Batch [300], Loss: 0.0380
# Epoch [22], Batch [500], Loss: 0.0469
# Epoch [22], Batch [700], Loss: 0.0417
# Epoch [22], Batch [900], Loss: 0.0475
# Epoch [23], Batch [100], Loss: 0.0200
# Epoch [23], Batch [300], Loss: 0.0408
# Epoch [23], Batch [500], Loss: 0.0418
# Epoch [23], Batch [700], Loss: 0.0377
# Epoch [23], Batch [900], Loss: 0.0443
# Epoch [24], Batch [100], Loss: 0.0110
# Epoch [24], Batch [300], Loss: 0.0348
# Epoch [24], Batch [500], Loss: 0.0415
# Epoch [24], Batch [700], Loss: 0.0442
# Epoch [24], Batch [900], Loss: 0.0354
# Epoch [25], Batch [100], Loss: 0.0176
# Epoch [25], Batch [300], Loss: 0.0343
# Epoch [25], Batch [500], Loss: 0.0311
# Epoch [25], Batch [700], Loss: 0.0326
# Epoch [25], Batch [900], Loss: 0.0380
# Training Complete!

# %%
plt.plot(log)
plt.xlabel('Batch number')
plt.ylabel('Loss')
plt.title('Training Loss over Time')
plt.show()

# %% [markdown]
# ## Evaluation

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for i, data in enumerate(dataloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            
            values, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    return avg_loss, accuracy

# Evaluate on training data
train_loss, train_accuracy = evaluate(model, trainloader, criterion, device)
print(f'Training Accuracy: {train_accuracy:.4f}, Training Loss: {train_loss:.4f}')

# Evaluate on test data
test_loss, test_accuracy = evaluate(model, testloader, criterion, device)
print(f'Test Accuracy: {test_accuracy:.4f}, Test Loss: {test_loss:.4f}')
# Out:
# Training Accuracy: 0.9968, Training Loss: 0.0121
# Test Accuracy: 0.9853, Test Loss: 0.0520

# %%
def visualize_predictions(model, testloader, device, num_images=20):
    model.eval()
    
    images, labels = next(iter(testloader))  # Get a batch of test images
    images, labels = images.to(device), labels.to(device)
    
    # Get predictions
    outputs = model(images)
    _, predicted = torch.max(outputs, 1)
    
    # Move images and labels back to CPU for visualization
    images = images.cpu().numpy()
    labels = labels.cpu().numpy()
    predicted = predicted.cpu().numpy()
    
    # Visualize the images with true and predicted labels
    fig, axes = plt.subplots(1, num_images, figsize=(20, 2))
    for i in range(num_images):
        ax = axes[i]
        ax.imshow(images[i].reshape(28, 28), cmap='gray')
        ax.set_title(f'True: {labels[i]}\nPred: {predicted[i]}')
        ax.axis('off')
    plt.show()

# Visualize predictions
visualize_predictions(model, testloader, device)
# Out:
# (64, 1, 28, 28)

# %% [markdown]
# ## Translation Invariance
#
# Now, we will pick an image and shift the position of the digit in it slightly such that the number remains entierly in the image. We will then feed it into our LeNet model and see its result. In the other notebook, we already performed this experiment and the MLP failed in making the same prediction and it detected the new image incorrectly. Let us see how LeNet performs.

# %%
# Select some image
dataiter = iter(testloader)
images, labels = next(dataiter)
image = images[0]

# Shift the image
transformed_image = torch.roll(image, shifts=(5, -5), dims=(2, 1))

# Display the images 
fig, axs = plt.subplots(1, 2)
axs[0].imshow(image.numpy().reshape(28, 28), cmap='gray')
axs[0].set_title('Original Image')
axs[1].imshow(transformed_image.numpy().reshape(28, 28), cmap='gray')
axs[1].set_title('Shifted Image')
for ax in axs:
    ax.axis('off')
    
plt.show()

# Load the two images in the preferred device
image = image.to(device)
transformed_image = transformed_image.to(device)

# Predict the original image
output = model(image.unsqueeze(0))
value, predicted1 = torch.max(output, 1)

# Predict the tranformed image
output = model(transformed_image.unsqueeze(0))
value, predicted2 = torch.max(output, 1)

# Print the outcome
print(f"Model Predicts the Original Image as Digit {predicted1.item()}")
print(f"Model Predicts the Transformed Image as Digit {predicted2.item()}")
# Out:
# Model Predicts the Original Image as Digit 7
# Model Predicts the Transformed Image as Digit 7

# %% [markdown]
# As we can see, unlike MLP (shown in the other notebook), the LeNet model keeps its correct prediciton even after the shifting transformation. This is a display of the translation invariance in work, a property that CNN's such as LeNet are known to have and MLP's do not.
